# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('modules are imported.')
# Out:
# modules are imported.

# %%
cd = pd.read_csv('time_series_covid19_confirmed_global.csv')
cd.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/9/20  9/10/20  \
# ...

# %%
cd.shape
# Out:
# (266, 245)

# %%
df = cd.drop(["Lat","Long"],axis=1)
df.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  9/9/20  9/10/20  \
# 0        0        0        0        0        0        0  ...   38544    38572
# ...

# %%
cd_aggregated = cd.groupby("Country/Region").sum()
cda = cd_aggregated.drop(["Lat","Long"],axis=1)
cda.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  9/9/20  9/10/20  \
# ...

# %%
cda.shape
# Out:
# (188, 241)

# %%
cda.loc["China"].plot()
cda.loc["Italy"].plot()
cda.loc["India"].plot()
plt.legend()

# %%
cda.loc["China"][:3].plot()

# %%
cda.loc["China"].diff().plot()

# %%
cda.loc["China"].diff().max()
# Out:
# 15136.0

# %%
cda.loc["India"].diff().max()
# Out:
# 97894.0

# %%
countries = list(cda.index)
max_inf = []
for c in countries :
    max_inf.append(cda.loc[c].diff().max())
cda["max_inf_rate"] = max_inf
cda.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  9/10/20  \
# Country/Region                                           ...
# ...

# %%
corona_data = pd.DataFrame(cda["max_inf_rate"])
corona_data.head()
# Out:
#                 max_inf_rate
# Country/Region
# Afghanistan            915.0
# Albania                178.0
# Algeria                675.0
# Andorra                 94.0
# Angola                 130.0

# %%
happy_report = pd.read_csv('2019.csv')
happy_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
uc = ["Overall rank","Score","Generosity","Perceptions of corruption"]
hr = happy_report.drop(uc,axis=1,inplace=True)
happy_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happy_report.set_index("Country or region",inplace=True)
happy_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
corona_data.head()
# Out:
#                 max_inf_rate
# Country/Region
# Afghanistan            915.0
# Albania                178.0
# Algeria                675.0
# Andorra                 94.0
# Angola                 130.0

# %%
corona_data.shape
# Out:
# (188, 1)

# %%
happy_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happy_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happy_report,how="inner")
data.head()
# Out:
#              max_inf_rate  GDP per capita  Social support  \
# Afghanistan         915.0           0.350           0.517
# Albania             178.0           0.947           0.848
# Algeria             675.0           1.002           1.160
# Argentina         12701.0           1.092           1.432
# Armenia             771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data.corr()
# Out:
#                               max_inf_rate  GDP per capita  Social support  \
# max_inf_rate                      1.000000        0.090481        0.043041
# GDP per capita                    0.090481        1.000000        0.757521
# Social support                    0.043041        0.757521        1.000000
# Healthy life expectancy           0.083299        0.859431        0.751632
# Freedom to make life choices      0.083290        0.394799        0.456317
#
#                               Healthy life expectancy  \
# max_inf_rate                                 0.083299
# GDP per capita                               0.859431
# Social support                               0.751632
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.423146
#
#                               Freedom to make life choices
# max_inf_rate                                      0.083290
# GDP per capita                                    0.394799
# ...

# %%
data.head()
# Out:
#              max_inf_rate  GDP per capita  Social support  \
# Afghanistan         915.0           0.350           0.517
# Albania             178.0           0.947           0.848
# Algeria             675.0           1.002           1.160
# Argentina         12701.0           1.092           1.432
# Armenia             771.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
x = data["GDP per capita"]
y = data["max_inf_rate"]
sns.scatterplot(x, np.log(y))

# %%
sns.regplot(x, np.log(y))
