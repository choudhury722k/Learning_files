# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
import tensorflow.keras.utils as ku 
import pandas as pd
import numpy as np
import string, os 
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
hotel_df = pd.read_csv('Seattle_Hotels_dirty.csv', encoding="latin-1")
all_descriptions = list(hotel_df.desc.values)

# %%
len(all_descriptions)
# Out:
# 152

# %%
corpus = [x for x in all_descriptions]
corpus[:1]
# Out:
# ['Located on the southern tip of Lake Union, the Hilton Garden Inn Seattle Downtown hotel is perfectly located for business and leisure. Non-Smoking\nHotel is 100% non-smoking, including e-cigarettes, in all guest rooms and public areas. A fee of up to $250 USD will be assessed for smoking in a non-smoking room. Please ask the Front Desk for locations of designated outdoor smoking areas. Check-in: 4:00 pm. Check-out: 12:00 pm. Cancellation policies may vary depending on the rate or dates of your reservation. Please refer to your reservation confirmation to verify your cancellation policy.\n']

# %%
t = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)
t.fit_on_texts(corpus)

# %%
# A dictionary of words and their counts.
print(t.word_counts)

# A dictionary of words and how many documents each appeared in.
print(t.word_docs)

# An integer count of the total number of documents that were used to fit the Tokenizer (i.e. total number of documents)
print(t.document_count)

# A dictionary of words and their uniquely assigned integers.
print(t.word_index)
# Out:
# OrderedDict([('located', 106), ('on', 128), ('the', 1236), ('southern', 1), ('tip', 1), ('of', 526), ('lake', 40), ('union', 31), ('hilton', 11), ('garden', 11), ('inn', 81), ('seattle', 463), ('downtown', 131), ('hotel', 293), ('is', 279), ('perfectly', 6), ('for', 213), ('business', 84), ('and', 1044), ('leisure', 18), ('non', 19), ('smoking', 29), ('100', 10), ('including', 48), ('e', 2), ('cigarettes', 2), ('in', 460), ('all', 104), ('guest', 61), ('rooms', 106), ('public', 9), ('areas', 19), ('a', 610), ('fee', 7), ('up', 46), ('to', 474), ('250', 3), ('usd', 2), ('will', 50), ('be', 49), ('assessed', 2), ('room', 81), ('please', 5), ('ask', 2), ('front', 12), ('desk', 12), ('locations', 2), ('designated', 6), ('outdoor', 24), ('check', 41), ('4', 15), ('00', 19), ('pm', 11), ('out', 36), ('12', 11), ('cancellation', 3), ('policies', 5), ('may', 5), ('vary', 3), ('depending', 2), ('rate', 8), ('or', 159), ('dates', 2), ('your', 184), ('reservation', 5), ('refer', 1), ('confirmation', 1), ('verify', 1), ('policy', 2), ("city's", 5), ('vibrant', 14), ('core', 5), ('sheraton', 8), ('grand', 13), ('provides', 9), ('gateway', 4), ('diverse', 5), ('sights', 1), ('sounds', 1), ('pacific', 41), ('northwest', 41), ('step', 11), ('our', 350), ('doors', 8), ('find', 31), ('gourmet', 1), ('dining', 36), ('bars', 6), ('world', 20), ('class', 12), ('shopping', 31), ('exciting', 6), ('entertainment', 11), ('iconic', 13), ('local', 47), ('attractions', 58), ('pike', 85), ('place', 100), ('market', 94), ('space', 90), ('needle', 63), ('chihuly', 3), ('glass', 10), ('museum', 41), ('as', 114), ('one', 76), ('only', 35), ('seven', 6), ('hotels', 28), ('north', 13), ('america', 3), ('earn', 3), ('esteemed', 1), ('designation', 1), ('guests', 59), ('can', 54), ('book', 11), ('confidently', 1), ('knowing', 1), ('they', 9), ('re', 3), ('receiving', 1), ('highest', 2), ('benchmark', 1), ('product', 1), ('service', 52), ('offerings', 2), ('available', 39), ('experience', 48), ('recently', 7), ('completed', 1), ('multimillion', 1), ('dollar', 1), ('transformation', 1), ('featuring', 26), ('new', 17), ('an', 88), ('expanded', 5), ('club', 17), ('lounge', 20), ('modern', 33), ('meeting', 26), ('event', 28), ('spaces', 11), ('gather', 1), ('stylish', 17), ('lobby', 26), ('enjoy', 90), ('private', 29), ('art', 42), ('collection', 6), ('artists', 2), ('while', 33), ('enjoying', 5), ('favorite', 7), ('beverage', 5), ('from', 218), ('starbucks', 12), ('features', 27), ('several', 5), ('options', 14), ('loulay', 1), ('kitchen', 17), ('bar', 32), ('by', 70), ('james', 1), ('beard', 1), ('award', 13), ('winning', 10), ('chef', 3), ('thierry', 1), ('rautureau', 1), ('not', 23), ('permitted', 6), ('within', 38), ('buildings', 5), ('themselves', 4), ('who', 8), ('smoke', 15), ('are', 142), ('do', 9), ('so', 15), ('outside', 16), ('we', 98), ('committed', 3), ('providing', 5), ('associates', 3), ('with', 278), ('free', 129), ('environment', 6), ('proud', 10), ('boast', 4), ('most', 42), ('comprehensive', 3), ('industry', 6), ('3pm', 2), ('12pm', 5), ('heart', 35), ('crowne', 5), ('plaza', 4), ('offers', 42), ('exceptional', 5), ('blend', 3), ('style', 27), ('comfort', 24), ('you', 215), ('ll', 1), ('notice', 1), ('cool', 5), ('comfortable', 30), ('unconventional', 1), ('touches', 4), ('that', 59), ('set', 4), ('us', 21), ('apart', 1), ('soon', 3), ('inside', 7), ('marvel', 2), ('at', 226), ('stunning', 7), ('views', 39), ('city', 59), ('lights', 4), ('relaxing', 12), ('sleep', 6), ('advantage', 12), ('beds', 15), ('complimentary', 60), ('wireless', 11), ('internet', 29), ('throughout', 9), ('amenities', 59), ('help', 11), ('relax', 24), ('like', 43), ('temple', 1), ('spa', 12), ('tight', 1), ('amenity', 1), ('kits', 1), ('lavender', 1), ('spray', 1), ('lotions', 1), ('rejuvenate', 1), ('unwind', 8), ('invigorating', 1), ('workout', 6), ('24', 38), ('hour', 28), ('fitness', 40), ('center', 146), ('get', 10), ('suggestions', 1), ('expert', 2), ('concierge', 3), ( ...
# defaultdict(<class 'int'>, {'hotel': 109, 'or': 83, 'of': 134, 'room': 54, 'may': 5, 'up': 33, 'your': 88, 'garden': 9, '12': 10, '4': 12, 'desk': 9, 'on': 77, 'smoking': 19, 'non': 15, 'union': 15, 'cancellation': 2, 'cigarettes': 2, 'public': 9, 'usd': 2, 'assessed': 2, 'locations': 2, 'vary': 3, 'and': 145, 'be': 38, 'rate': 8, 'tip': 1, 'out': 33, 'dates': 2, 'hilton': 9, 'a': 141, 'perfectly': 6, 'please': 4, 'outdoor': 21, 'e': 2, 'check': 24, 'policies': 5, 'ask': 2, 'to': 133, 'located': 83, 'designated': 6, 'inn': 35, 'southern': 1, 'policy': 2, 'depending': 2, 'all': 69, 'will': 31, 'reservation': 4, 'leisure': 16, '00': 10, 'refer': 1, 'front': 12, '250': 3, 'is': 122, 'including': 35, '100': 10, 'lake': 19, 'rooms': 73, 'verify': 1, 'for': 100, 'the': 148, 'downtown': 84, 'areas': 17, 'confirmation': 1, 'pm': 6, 'seattle': 129, 'guest': 47, 'business': 50, 'in': 139, 'fee': 6, 'product': 1, 'beard': 1, 'completed': 1, 'class': 11, 'seven': 5, 'core': 5, 'we': 54, 'designation': 1, 'rautureau': 1, 'proud': 9, 'artists': 2, 'world': 17, 'market': 77, 'our': 105, 'james': 1, 'pike': 74, 'only': 30, 'features': 23, 're': 2, 'north': 8, 'enjoy': 59, 'providing': 5, 'earn': 3, 'transformation': 1, 'options': 13, 'boast': 4, 'industry': 6, 'environment': 6, 'loulay': 1, 'sheraton': 3, 'winning': 10, 'local': 41, 'confidently': 1, 'enjoying': 5, 'an': 61, 'starbucks': 12, 'hotels': 22, 'esteemed': 1, 'stylish': 16, 'as': 65, 'bar': 27, 'themselves': 4, 'museum': 30, 'new': 15, 'chef': 3, 'lobby': 23, 'provides': 9, 'attractions': 50, 'gourmet': 1, 'one': 51, "city's": 4, '3pm': 2, 'several': 5, 'beverage': 5, 'club': 11, 'pacific': 31, 'experience': 43, 'do': 9, 'lounge': 17, 'permitted': 3, 'art': 33, 'highest': 2, 'not': 21, 'benchmark': 1, 'private': 24, 'thierry': 1, 'award': 11, 'comprehensive': 3, 'most': 36, 'associates': 3, 'sights': 1, 'shopping': 29, 'available': 29, 'step': 11, 'exciting': 6, 'they': 7, 'grand': 9, 'gather': 1, 'who': 8, 'committed': 3, '12pm': 5, 'while': 28, 'knowing': 1, 'modern': 28, 'with': 121, 'needle': 56, 'place': 83, 'iconic': 12, 'expanded': 5, 'event': 20, 'entertainment': 11, 'spaces': 11, 'northwest': 33, 'america': 3, 'by': 53, 'gateway': 2, 'featuring': 25, 'meeting': 23, 'collection': 6, 'sounds': 1, 'chihuly': 3, 'vibrant': 14, 'receiving': 1, 'offerings': 2, 'dining': 28, 'book': 11, 'favorite': 7, 'within': 33, 'buildings': 5, 'glass': 9, 'kitchen': 15, 'outside': 16, 'multimillion': 1, 'are': 79, 'doors': 8, 'recently': 7, 'find': 28, 'can': 39, 'bars': 6, 'so': 15, 'diverse': 5, 'guests': 41, 'smoke': 9, 'space': 73, 'from': 108, 'free': 63, 'dollar': 1, 'service': 42, 'plaza': 2, 'happy': 6, 'help': 10, 'fitness': 35, 'kits': 1, 'cuisine': 10, 'stunning': 7, 'beds': 14, 'unconventional': 1, 'cool': 5, 'tight': 1, 'll': 1, 'notice': 1, 'suggestions': 1, 'throughout': 8, 'amenity': 1, 'specials': 2, 'spa': 12, 'at': 94, 'restaurant': 27, 'wired': 4, 'crowne': 2, 'complimentary': 41, 'hour': 26, 'grille': 1, 'that': 40, 'drink': 5, 'views': 30, 'sleep': 5, 'rejuvenate': 1, 'get': 10, 'marvel': 2, 'has': 31, 'city': 43, 'offer': 45, 'blend': 3, 'workout': 6, 'wireless': 10, 'savor': 6, 'regatta': 1, 'completely': 3, '24': 33, 'like': 34, 'advantage': 12, '7pm': 1, 'lavender': 1, 'us': 20, 'touches': 4, 'relax': 20, 'inside': 7, 'internet': 24, 'center': 83, 'lotions': 1, 'heart': 31, 'relaxing': 12, 'where': 24, 'comfort': 22, 'spray': 1, 'unwind': 7, 'lights': 4, 'emerald': 14, 'exceptional': 5, 'this': 44, 'comfortable': 29, 'come': 15, 'you': 94, 'temple': 1, 'invigorating': 1, 'high': 25, 'set': 4, 'amenities': 50, 'daily': 9, 'apart': 1, 'offers': 34, 'style': 24, 'allow': 2, 'concierge': 3, 'soon': 3, 'speed': 23, 'sumptuous': 1, 'monthly': 1, 'expert': 2, 'access': 47, '4pm': 2, '3': 7, 'bell': 2, 'louis': 1, 'convention': 22, 'tallest': 1, 'sounders': 4, 'rest': 4, 'sky': 2, 'sampling': 1, 'what': 6, 'mile': 12, 'houses': 5, '5th': 4, 'viewing': 1, 'state': 24, 'rack': ...
# 152
# {'the': 1, 'and': 2, 'a': 3, 'of': 4, 'to': 5, 'seattle': 6, 'in': 7, 'our': 8, 'hotel': 9, 'is': 10, 'with': 11, 'at': 12, 'from': 13, 'you': 14, 'for': 15, 'your': 16, 'or': 17, 'center': 18, 'are': 19, 'downtown': 20, 'free': 21, 'on': 22, 'as': 23, 'located': 24, 'rooms': 25, 'all': 26, 'stay': 27, 'place': 28, 'we': 29, 'market': 30, 'airport': 31, 'space': 32, 'enjoy': 33, 'an': 34, 'pike': 35, 'business': 36, 'inn': 37, 'room': 38, 'just': 39, 'one': 40, 'by': 41, 'breakfast': 42, 'washington': 43, 'needle': 44, 'suites': 45, 'this': 46, 'also': 47, 'guest': 48, 'complimentary': 49, 'guests': 50, 'that': 51, 'city': 52, 'amenities': 53, 'access': 54, 'attractions': 55, 'offer': 56, 'away': 57, 'home': 58, 'can': 59, 'service': 60, 'will': 61, 'be': 62, 'best': 63, 'including': 64, 'experience': 65, 'local': 66, 'near': 67, 'up': 68, 'like': 69, 'easy': 70, 'art': 71, 'most': 72, 'offers': 73, 'area': 74, 'make': 75, 'check': 76, 'pacific': 77, 'northwest': 78, 'museum': 79, 'has': 80, 'minutes': 81, 'university': 82, 'lake': 83, 'fitness': 84, 'available': 85, 'views': 86, 'bed': 87, 'within': 88, '24': 89, 'great': 90, 'waterfront': 91, 'day': 92, 'when': 93, 'coffee': 94, 'out': 95, 'dining': 96, 'pool': 97, 'only': 98, 'heart': 99, 'park': 100, 'wi': 101, 'fi': 102, 'seattle\x92s': 103, 'restaurants': 104, 'have': 105, 'modern': 106, 'while': 107, 'high': 108, 'location': 109, 'field': 110, 'well': 111, 'bar': 112, 'parking': 113, 'union': 114, 'find': 115, 'shopping': 116, 'time': 117, 'many': 118, 'it': 119, 'close': 120, 'neighborhood': 121, 'comfortable': 122, 'take': 123, 'international': 124, 'shuttle': 125, 'smoking': 126, 'private': 127, 'internet': 128, 'restaurant': 129, 'state': 130, 'more': 131, 'perfect': 132, 'spacious': 133, 'hotels': 134, 'event': 135, 'hour': 136, 'square': 137, 'friendly': 138, 'walk': 139, 'each': 140, 'every': 141, 'queen': 142, 'features': 143, 'style': 144, 'where': 145, 'speed': 146, 'full': 147, 'featuring': 148, 'meeting': 149, 'lobby': 150, 'you\x92re': 151, 'district': 152, '\x96': 153, 'two': 154, 'street': 155, 'light': 156, 'work': 157, 'suite': 158, 'travel': 159, 'hot': 160, 'wifi': 161, 'such': 162, 'tacoma': 163, 'family': 164, 'outdoor': 165, 'comfort': 166, 'relax': 167, 'historic': 168, 'not': 169, 'convention': 170, 'distance': 171, 'need': 172, 'miles': 173, 'its': 174, 'living': 175, 'sea': 176, 'travelers': 177, "seattle's": 178, 'us': 179, 'designed': 180, 'walking': 181, 'visit': 182, 'blocks': 183, 'some': 184, 'whether': 185, 'other': 186, 'flat': 187, 'hill': 188, 'km': 189, 'world': 190, 'lounge': 191, 'sound': 192, 'offering': 193, 'explore': 194, 'you\x92ll': 195, 'steps': 196, 'welcome': 197, 'next': 198, '5': 199, 'feature': 200, 'non': 201, 'areas': 202, '00': 203, 'here': 204, 'safeco': 205, 'than': 206, 'if': 207, 'rail': 208, 'first': 209, "you'll": 210, 'south': 211, 'include': 212, 'wa': 213, 'site': 214, 'sure': 215, 'motel': 216, 'leisure': 217, 'luxury': 218, 'off': 219, 'morning': 220, 'building': 221, 'amazon': 222, 'property': 223, 'minute': 224, 'new': 225, 'club': 226, 'stylish': 227, 'kitchen': 228, 'guestrooms': 229, 'top': 230, 'fresh': 231, 'short': 232, 'everything': 233, 'equipped': 234, 'food': 235, 'screen': 236, 'through': 237, 'outside': 238, 'come': 239, 'emerald': 240, 'nearby': 241, 'centurylink': 242, 'puget': 243, 'meetings': 244, 'feet': 245, 'across': 246, 'music': 247, 'indoor': 248, 'convenience': 249, 'few': 250, 'convenient': 251, 'capitol': 252, '4': 253, 'smoke': 254, 'so': 255, 'beds': 256, 'west': 257, 'avenue': 258, 'see': 259, 'pioneer': 260, 'hyatt': 261, 'famous': 262, 'extended': 263, 'both': 264, 'unique': 265, 'tv': 266, 'anne': 267, 'fun': 268, 'traveling': 269, 'flight': 270, 'vibrant': 271, 'options': 272, 'mile': 273, 'which': 274, 'situated': 275, 'signature': 276, 'urban': 277, 'shops': 278, 'right': 279, 'bay': 280, 'plus': 281, 'no': 282, 'around': 283, 'tac': 284, 'start': 285, 'events': 286, 'gr ...

# %%
print('Found %s unique tokens.' % len(t.word_index))
# Out:
# Found 3428 unique tokens.

# %%
# Tokenization
t = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)

def get_sequence_of_tokens(corpus):
    t.fit_on_texts(corpus)
    total_words = len(t.word_index) + 1
    
    input_sequences = []
    for line in corpus:
        token_list = t.texts_to_sequences([line])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)
            
    return input_sequences, total_words
input_sequences, total_words = get_sequence_of_tokens(corpus)

# %%
input_sequences[:10]
# Out:
# [[24, 22],
#  [24, 22, 1],
#  [24, 22, 1, 1750],
#  [24, 22, 1, 1750, 1751],
#  [24, 22, 1, 1750, 1751, 4],
#  [24, 22, 1, 1750, 1751, 4, 83],
#  [24, 22, 1, 1750, 1751, 4, 83, 114],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1, 334],
#  [24, 22, 1, 1750, 1751, 4, 83, 114, 1, 334, 335]]

# %%
total_words
# Out:
# 3429

# %%
# pad sequences 
def generate_padded_sequences(input_sequences):
    max_sequence_len = max([len(x) for x in input_sequences])
    input_sequences = np.array(pad_sequences(input_sequences, maxlen = max_sequence_len, padding = 'pre'))
    predictors, label = input_sequences[:,:-1],input_sequences[:,-1]
    label = ku.to_categorical(label, num_classes = total_words)
    
    return predictors, label, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(input_sequences)

# %%
def create_model(max_sequence_len, total_words):
    model = Sequential()
    
    # Add Input Embedding Layer
    model.add(Embedding(total_words, 10, input_length=max_sequence_len - 1))
    
    # Add Hidden Layer 1 - LSTM Layer
    model.add(LSTM(100))
    model.add(Dropout(0.1))
    
    # Add Output Layer
    model.add(Dense(total_words, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

model = create_model(max_sequence_len, total_words)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 505, 10)           34290
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               44400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3429)              346329
# =================================================================
# Total params: 425,019
# Trainable params: 425,019
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(predictors, label, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 758/758 [==============================] - 27s 28ms/step - loss: 6.6791 - accuracy: 0.0497
# Epoch 2/100
# 758/758 [==============================] - 22s 28ms/step - loss: 6.3612 - accuracy: 0.0574
# Epoch 3/100
# 758/758 [==============================] - 22s 29ms/step - loss: 6.2005 - accuracy: 0.0683
# Epoch 4/100
# 758/758 [==============================] - 22s 29ms/step - loss: 5.9996 - accuracy: 0.0827
# Epoch 5/100
# 758/758 [==============================] - 22s 29ms/step - loss: 5.8148 - accuracy: 0.0921
# Epoch 6/100
# 758/758 [==============================] - 23s 30ms/step - loss: 5.6235 - accuracy: 0.1031
# Epoch 7/100
# 758/758 [==============================] - 22s 29ms/step - loss: 5.4220 - accuracy: 0.1141
# Epoch 8/100
# 758/758 [==============================] - 22s 29ms/step - loss: 5.2223 - accuracy: 0.1279
# Epoch 9/100
# 758/758 [==============================] - 22s 29ms/step - loss: 5.0261 - accuracy: 0.1420
# Epoch 10/100
# 758/758 [==============================] - 22s 29ms/step - loss: 4.8378 - accuracy: 0.1550
# Epoch 11/100
# 758/758 [==============================] - 23s 30ms/step - loss: 4.6603 - accuracy: 0.1666
# Epoch 12/100
# 758/758 [==============================] - 21s 28ms/step - loss: 4.4914 - accuracy: 0.1784
# Epoch 13/100
# 758/758 [==============================] - 21s 28ms/step - loss: 4.3376 - accuracy: 0.1921
# Epoch 14/100
# 758/758 [==============================] - 21s 28ms/step - loss: 4.1782 - accuracy: 0.2080
# Epoch 15/100
# 758/758 [==============================] - 21s 27ms/step - loss: 4.0281 - accuracy: 0.2251
# Epoch 16/100
# 758/758 [==============================] - 21s 27ms/step - loss: 3.8852 - accuracy: 0.2396
# Epoch 17/100
# 758/758 [==============================] - 21s 28ms/step - loss: 3.7500 - accuracy: 0.2576
# Epoch 18/100
# 758/758 [==============================] - 21s 28ms/step - loss: 3.6220 - accuracy: 0.2748
# Epoch 19/100
# 758/758 [==============================] - 21s 28ms/step - loss: 3.4979 - accuracy: 0.2966
# Epoch 20/100
# 758/758 [==============================] - 21s 28ms/step - loss: 3.3784 - accuracy: 0.3130
# Epoch 21/100
# 758/758 [==============================] - 22s 29ms/step - loss: 3.2701 - accuracy: 0.3295
# Epoch 22/100
# 758/758 [==============================] - 22s 29ms/step - loss: 3.1608 - accuracy: 0.3486
# Epoch 23/100
# 758/758 [==============================] - 21s 28ms/step - loss: 3.0647 - accuracy: 0.3625
# Epoch 24/100
# 758/758 [==============================] - 21s 27ms/step - loss: 2.9764 - accuracy: 0.3756
# Epoch 25/100
# 758/758 [==============================] - 21s 27ms/step - loss: 2.8886 - accuracy: 0.3910
# Epoch 26/100
# 758/758 [==============================] - 21s 27ms/step - loss: 2.8105 - accuracy: 0.4023
# Epoch 27/100
# 758/758 [==============================] - 21s 27ms/step - loss: 2.7353 - accuracy: 0.4141
# Epoch 28/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.6659 - accuracy: 0.4283
# Epoch 29/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.5933 - accuracy: 0.4403
# Epoch 30/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.5268 - accuracy: 0.4503
# Epoch 31/100
# 758/758 [==============================] - 22s 28ms/step - loss: 2.4674 - accuracy: 0.4628
# Epoch 32/100
# 758/758 [==============================] - 22s 28ms/step - loss: 2.4119 - accuracy: 0.4716
# Epoch 33/100
# 758/758 [==============================] - 22s 29ms/step - loss: 2.3585 - accuracy: 0.4796
# Epoch 34/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.3037 - accuracy: 0.4902
# Epoch 35/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.2490 - accuracy: 0.4962
# Epoch 36/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.2018 - accuracy: 0.5100
# Epoch 37/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.1597 - accuracy: 0.5183
# Epoch 38/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.1170 - accuracy: 0.5234
# Epoch 39/100
# 758/758 [==============================] - 21s 28ms/step - loss: 2.0710 - accuracy: 0.5346
# Epoch 40/100
# 758/758 [==============================] - 22s 29ms/step - loss: 2.0340 - accuracy: 0.5372
# Epoch 41/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.9992 - accuracy: 0.5431
# Epoch 42/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.9584 - accuracy: 0.5528
# Epoch 43/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.9276 - accuracy: 0.5569
# Epoch 44/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.8893 - accuracy: 0.5632
# Epoch 45/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.8599 - accuracy: 0.5708
# Epoch 46/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.8294 - accuracy: 0.5754
# Epoch 47/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.7998 - accuracy: 0.5828
# Epoch 48/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.7705 - accuracy: 0.5877
# Epoch 49/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.7411 - accuracy: 0.5902
# Epoch 50/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.7105 - accuracy: 0.5970
# Epoch 51/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.6920 - accuracy: 0.6029
# Epoch 52/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.6692 - accuracy: 0.6060
# Epoch 53/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.6899 - accuracy: 0.6010
# Epoch 54/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.6425 - accuracy: 0.6092
# Epoch 55/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.5967 - accuracy: 0.6214
# Epoch 56/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.5719 - accuracy: 0.6254
# Epoch 57/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.5521 - accuracy: 0.6285
# Epoch 58/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.5321 - accuracy: 0.6330
# Epoch 59/100
# 758/758 [==============================] - 22s 28ms/step - loss: 1.5128 - accuracy: 0.6381
# Epoch 60/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.4994 - accuracy: 0.6366
# Epoch 61/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4841 - accuracy: 0.6404
# Epoch 62/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4589 - accuracy: 0.6474
# Epoch 63/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.4458 - accuracy: 0.6477
# Epoch 64/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4197 - accuracy: 0.6538
# Epoch 65/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4097 - accuracy: 0.6546
# Epoch 66/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3978 - accuracy: 0.6543
# Epoch 67/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.3820 - accuracy: 0.6595
# Epoch 68/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.3595 - accuracy: 0.6638
# Epoch 69/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3621 - accuracy: 0.6629
# Epoch 70/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3511 - accuracy: 0.6641
# Epoch 71/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.6521 - accuracy: 0.6113
# Epoch 72/100
# 758/758 [==============================] - 22s 30ms/step - loss: 2.0692 - accuracy: 0.5167
# Epoch 73/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.7692 - accuracy: 0.5745
# Epoch 74/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.6404 - accuracy: 0.6024
# Epoch 75/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.5563 - accuracy: 0.6166
# Epoch 76/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.5064 - accuracy: 0.6315
# Epoch 77/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4710 - accuracy: 0.6391
# Epoch 78/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4401 - accuracy: 0.6437
# Epoch 79/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.4020 - accuracy: 0.6539
# Epoch 80/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.3869 - accuracy: 0.6543
# Epoch 81/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3607 - accuracy: 0.6607
# Epoch 82/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3341 - accuracy: 0.6678
# Epoch 83/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.3131 - accuracy: 0.6713
# Epoch 84/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.3015 - accuracy: 0.6733
# Epoch 85/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2851 - accuracy: 0.6753
# Epoch 86/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.2797 - accuracy: 0.6786
# Epoch 87/100
# 758/758 [==============================] - 22s 29ms/step - loss: 1.2637 - accuracy: 0.6811
# Epoch 88/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2389 - accuracy: 0.6875
# Epoch 89/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2268 - accuracy: 0.6915
# Epoch 90/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2151 - accuracy: 0.6924
# Epoch 91/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2063 - accuracy: 0.6919
# Epoch 92/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.2005 - accuracy: 0.6914
# Epoch 93/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1857 - accuracy: 0.6970
# Epoch 94/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1737 - accuracy: 0.6970
# Epoch 95/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1717 - accuracy: 0.6974
# Epoch 96/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1628 - accuracy: 0.7001
# Epoch 97/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.1419 - accuracy: 0.7074
# Epoch 98/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1390 - accuracy: 0.7062
# Epoch 99/100
# 758/758 [==============================] - 21s 28ms/step - loss: 1.1301 - accuracy: 0.7071
# Epoch 100/100
# 758/758 [==============================] - 21s 27ms/step - loss: 1.1227 - accuracy: 0.7083

# %%
def generate_text(seed_text, next_words, model, max_seq_len):
    for _ in range(next_words):
        token_list = t.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding='pre')
        
        predicted = model.predict_classes(token_list, verbose=0)
        
        output_word = ''
        
        for word,index in t.word_index.items():
            if index == predicted:
                output_word = word
                break
                
        seed_text = seed_text + " " + output_word
        
    return seed_text.title()

# %%
print(generate_text("hilton seattle downtown", 100, model, max_sequence_len))
print()
print(generate_text("best western seattle airport hotel", 200, model, max_sequence_len))
print()
print(generate_text('located in the heart of downtown seattle', 300, model, max_sequence_len))
# Out:
